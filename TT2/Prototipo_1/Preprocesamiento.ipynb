# %%
import pandas as pd
import numpy as np

# %%
# Cargar el CSV
df_naves_industriales = pd.read_csv('Prueba.csv', delimiter=',')

# %%
# Inspeccionar el CSV
print(df_naves_industriales.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143 entries, 0 to 142
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   N                  143 non-null    int64
#  1   PARQUE INDUSTRIAL  143 non-null    object
#  2   MUNICIPIO          143 non-null    object
#  3   DIRECCION          143 non-null    object
#  4   ADMINISTRACION     143 non-null    object
#  5   LATITUD            143 non-null    float64
#  6   LONGITUD           143 non-null    float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 7.9+ KB
# None

# %%
# Dropear columnas innecesarias
df_naves_industriales = df_naves_industriales.drop(columns=['N','MUNICIPIO','DIRECCION','ADMINISTRACION'])

# Renombrar columnas para facilitar el acceso
df_naves_industriales = df_naves_industriales.rename(columns={
    'LATITUD': 'latitud',
    'LONGITUD': 'longitud',
    'PARQUE INDUSTRIAL': 'nombre'
})

# Rsetear el índice
df_naves_industriales = df_naves_industriales.reset_index(drop=True)

print(df_naves_industriales.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143 entries, 0 to 142
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   nombre    143 non-null    object
#  1   latitud   143 non-null    float64
#  2   longitud  143 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 3.5+ KB
# None

# %%
print(df_naves_industriales.head())
# Out:
#                              nombre    latitud   longitud
# 0        PARQUE INDUSTRIAL POLO INN  20.253056 -99.915000
# 1       PARQUE INDUSTRIAL JILOTEPEC  19.979619 -99.528053
# 2     PARQUE INDUSTRIAL EL CONVENTO  19.715366 -99.203221
# 3  PARQUE INDUSTRIAL EL CONVENTO II  19.704083 -99.215111
# 4          PARQUE INDUSTRIAL TREBOL  19.721556 -99.203739

# %%
# Guardar el DataFrame limpio a un nuevo CSV
df_naves_industriales.to_csv('Naves_Industriales_Limpio.csv', index=False)
